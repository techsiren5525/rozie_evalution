# %%
import numpy as np
import pandas as pd
import math, string, re
import sklearn
import random
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer

import spacy
nlp = spacy.load('lib/en_core_web_sm-2.3.1/en_core_web_sm/en_core_web_sm-2.3.1/')

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk import word_tokenize

import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dinuka\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Dinuka\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
def pos_tag_word(w,l='x'):
    return (w,nlp(w)[0].tag_,l)

def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]

    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

def _entity_string_to_dict(entity_string):
    entity_extract_pattern = re.compile(r'(?P<entity>\[(?P<value>.+?)\]\((?P<name_and_synonyms>.+?)\))')
    new_string = ''
    start = 0
    output = dict()
    output['entities'] = []
    for item in re.finditer(entity_extract_pattern, entity_string):
        d = dict()
        new_string += entity_string[start:item.start()]
        start = item.start()
        d['span_start'] = len(new_string)
        new_string += item.group('value')
        d['span_end'] = len(new_string)
        start += len(item.group('entity'))
        d['entity_value'] = item.group('value')

        syn_items = item.group('name_and_synonyms').split('|')
        d['entity_type'] = syn_items[0]
        d['synonyms'] = list()
        if len(syn_items) > 1:
            d['synonyms'] += [t for t in syn_items[1:]]

        output['entities'].append(d)
    new_string += entity_string[start:]
    output['statement'] = new_string
    return output

# %%
data = pd.read_csv("evalution_data_set.csv")
data.head()
# Out:
#                   label                                         expression
# 0  intent_flight_search                                      flight search
# 1  intent_flight_search                 can you help me to find a flight ?
# 2  intent_flight_search              please help me to search for a flight
# 3  intent_flight_search  I want a flight from [Colombo](Departure.Airpo...
# 4  intent_flight_search  We need a flight from [jfk](Departure.Airport....

# %%
data['entity'] = data.apply(lambda x: _entity_string_to_dict(x['expression']), axis=1)
data['statement'] = data.apply(lambda x: _entity_string_to_dict(x['expression'])['statement'], axis=1)
data.head()
# Out:
#                   label                                         expression  \
# 0  intent_flight_search                                      flight search
# 1  intent_flight_search                 can you help me to find a flight ?
# 2  intent_flight_search              please help me to search for a flight
# 3  intent_flight_search  I want a flight from [Colombo](Departure.Airpo...
# 4  intent_flight_search  We need a flight from [jfk](Departure.Airport....
#
#                                               entity  \
# 0     {'entities': [], 'statement': 'flight search'}
# 1  {'entities': [], 'statement': 'can you help me...
# 2  {'entities': [], 'statement': 'please help me ...
# 3  {'entities': [{'span_start': 21, 'span_end': 2...
# 4  {'entities': [{'span_start': 22, 'span_end': 2...
#
#                                statement
# 0                          flight search
# 1     can you help me to find a flight ?
# 2  please help me to search for a flight
# 3           I want a flight from Colombo
# 4      We need a flight from jfk airport

# %%
sent_list=[]
for ent in data['entity']:
    word_list = []
    last_index= 0 
    for entobj in ent['entities']:
        words_before = ent['statement'][last_index:int(entobj["span_start"])]
        for word in words_before.split():
            word_list.append(pos_tag_word(word))
        last_index = int(entobj["span_end"])
        word_list.append((entobj["entity_value"],nlp(entobj["entity_value"])[0].tag_,entobj["entity_type"]))
    for word in ent['statement'][last_index:].split():
        word_list.append(pos_tag_word(word))
    sent_list.append(word_list)

# %%
random.shuffle(sent_list)
test_per = 0.7
n=int(test_per*len(sent_list))
train_se = sent_list[:n].copy()
test_se = sent_list[n:].copy()


tokenized_data = pd.DataFrame(sent_list[50],columns=['Token', 'POS', 'Label'])
tokenized_data
# Out:
#      Token  POS                          Label
# 0      I'm  PRP                              x
# 1  leaving  VBG                              x
# 2     from   IN                              x
# 3      LAX  NNP  Departure.Airport.AirportCode
# 4       to   IN                              x
# 5  colombo  NNP    Arrival.Airport.AirportCode
# 6       on   IN                              x
# 7   flight   NN                              x
# 8      581   CD                   FlightNumber

# %%
data['entity'][5]['entities']

entity=[]
array = data['entity'].copy()
for x in array:
    for en in x["entities"]:
        en['sentence'] = x['statement']
        entity.append(en)
        
newdf = pd.DataFrame(entity)
newdf
# Out:
#      span_start  span_end entity_value                    entity_type  \
# 0            21        28      Colombo  Departure.Airport.AirportCode
# 1            22        25          jfk  Departure.Airport.AirportCode
# 2            30        37      Calgary  Departure.Airport.AirportCode
# 3            19        26      colombo    Arrival.Airport.AirportCode
# 4            27        32        Dubai    Arrival.Airport.AirportCode
# ..          ...       ...          ...                            ...
# 114          53        61     Heathrow    Arrival.Airport.AirportCode
# 115          17        20          234                   FlightNumber
# 116          26        29          jfk  Departure.Airport.AirportCode
# 117          41        48      Calgary    Arrival.Airport.AirportCode
# 118          49        57     tomorrow        Departure.EstimatedDate
#
#                      synonyms  \
# 0         [cmb, colombo, CMB]
# 1      [JFK, John F. Kennedy]
# 2         [calgary, yyc, YYC]
# 3         [CMB, Colombo, cmb]
# 4           [dubai, DXB, dxb]
# ..                        ...
# 114      [heathrow, LHR, lhr]
# 115      [600, 666, 923, 234]
# 116    [JFK, John F. Kennedy]
# 117       [calgary, yyc, YYC]
# 118  [today, Tomorrow, Today]
#
#                                               sentence
# 0                         I want a flight from Colombo
# 1                    We need a flight from jfk airport
# 2                can you find me a flight from Calgary
# 3                           I want a flight to colombo
# 4                     please find me a flight to Dubai
# ..                                                 ...
# 114  on next friday I'm taking flight 874 from Calg...
# 115  we are on flight 234 from jfk airport to Calga...
# 116  we are on flight 234 from jfk airport to Calga...
# 117  we are on flight 234 from jfk airport to Calga...
# 118  we are on flight 234 from jfk airport to Calga...
#
# [119 rows x 6 columns]

# %%
X_train = [sent2features(s) for s in train_se]
y_train = [sent2labels(s) for s in train_se]

X_test = [sent2features(s) for s in test_se]
y_test = [sent2labels(s) for s in test_se]

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True
)
crf.fit(X_train, y_train)
# Out:
# C:\Users\Dinuka\anaconda3\lib\site-packages\sklearn\base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# CRF(algorithm='lbfgs', all_possible_transitions=True, c1=0.1, c2=0.1,
#     keep_tempfiles=None, max_iterations=100)

# %%
labels = list(crf.classes_)
labels.remove('x')
labels
# Out:
# ['Departure.Airport.AirportCode',
#  'Arrival.Airport.AirportCode',
#  'FlightNumber',
#  'Departure.EstimatedDate']

# %%
from sklearn_crfsuite import metrics

y_pred = crf.predict(X_test)
print("Accuracy : {}".format(metrics.flat_f1_score(y_test, y_pred,
                      average='weighted', labels=labels)))
# Out:
# Accuracy : 0.9707524985302763

# %%
print('Train set classification report: \n\n{}'.format(metrics.flat_classification_report(
y_test, y_pred, labels=labels, digits=3
)))
# Out:
# Train set classification report:
#
#                                precision    recall  f1-score   support
#
# Departure.Airport.AirportCode      0.929     1.000     0.963        13
#   Arrival.Airport.AirportCode      1.000     0.750     0.857         4
#                  FlightNumber      1.000     1.000     1.000         6
#       Departure.EstimatedDate      1.000     1.000     1.000        13
#
#                     micro avg      0.972     0.972     0.972        36
#                     macro avg      0.982     0.938     0.955        36
#                  weighted avg      0.974     0.972     0.971        36
# C:\Users\Dinuka\anaconda3\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass labels=['Departure.Airport.AirportCode', 'Arrival.Airport.AirportCode', 'FlightNumber', 'Departure.EstimatedDate'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "

# %%
pred_data = [ pos_tag_word(w,'') for w in ["we","are","planning","to","leave","next monday","on","flight","981"]]
pd.DataFrame(pred_data)
# Out:
#              0    1 2
# 0           we  PRP
# 1          are  VBP
# 2     planning   NN
# 3           to   IN
# 4        leave   VB
# 5  next monday   JJ
# 6           on   IN
# 7       flight   NN
# 8          981   CD

# %%
feature_arr = [sent2features(vbg) for vbg in [pred_data]]
pd.DataFrame(feature_arr[0])
# Out:
#    bias word.lower() word[-3:] word[-2:]  word.isupper()  word.istitle()  \
# 0   1.0           we        we        we           False           False
# 1   1.0          are       are        re           False           False
# 2   1.0     planning       ing        ng           False           False
# 3   1.0           to        to        to           False           False
# 4   1.0        leave       ave        ve           False           False
# 5   1.0  next monday       day        ay           False           False
# 6   1.0           on        on        on           False           False
# 7   1.0       flight       ght        ht           False           False
# 8   1.0          981       981        81           False           False
#
#    word.isdigit() postag postag[:2]   BOS  ... +1:word.istitle()  \
# 0           False    PRP         PR  True  ...             False
# 1           False    VBP         VB   NaN  ...             False
# 2           False     NN         NN   NaN  ...             False
# 3           False     IN         IN   NaN  ...             False
# 4           False     VB         VB   NaN  ...             False
# 5           False     JJ         JJ   NaN  ...             False
# 6           False     IN         IN   NaN  ...             False
# 7           False     NN         NN   NaN  ...             False
# 8            True     CD         CD   NaN  ...               NaN
#
#   +1:word.isupper() +1:postag +1:postag[:2] -1:word.lower() -1:word.istitle()  \
# 0             False       VBP            VB             NaN               NaN
# 1             False        NN            NN              we             False
# 2             False        IN            IN             are             False
# 3             False        VB            VB        planning             False
# 4             False        JJ            JJ              to             False
# 5             False        IN            IN           leave             False
# 6             False        NN            NN     next monday             False
# 7             False        CD            CD              on             False
# 8               NaN       NaN           NaN          flight             False
#
#   -1:word.isupper() -1:postag -1:postag[:2]   EOS
# 0               NaN       NaN           NaN   NaN
# 1             False       PRP            PR   NaN
# 2             False       VBP            VB   NaN
# 3             False        NN            NN   NaN
# 4             False        IN            IN   NaN
# 5             False        VB            VB   NaN
# 6             False        JJ            JJ   NaN
# 7             False        IN            IN   NaN
# 8             False        NN            NN  True
#
# [9 rows x 21 columns]

# %%
y_pred = crf.predict(feature_arr)
print(y_pred)
# Out:
# [['x', 'x', 'x', 'x', 'x', 'Departure.EstimatedDate', 'x', 'x', 'FlightNumber']]
